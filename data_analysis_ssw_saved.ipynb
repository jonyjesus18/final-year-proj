# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

import os

# %%
# load your time histories into a Pandas DataFrame
df = pd.read_csv("ssw_events_saved/ssw_t0_2006-02-11.csv")

# %%
df
# Out:
#          dates  wind_eastward_mean  wind_eastward_mean_selection  \
# 0   2006-01-27           -8.416429                      4.359548
# 1   2006-01-28           -5.483050                     17.222801
# 2   2006-01-29           -4.004173                     23.732811
# 3   2006-01-30           -2.991445                     22.241640
# 4   2006-01-31           -1.365972                     27.645525
# 5   2006-02-01           -0.740848                     25.142765
# 6   2006-02-02            0.382105                     26.038445
# 7   2006-02-03            1.000594                     18.003941
# 8   2006-02-04            1.458551                     11.408140
# 9   2006-02-05            2.111493                      6.873853
# 10  2006-02-06            2.645339                      4.394864
# 11  2006-02-07            3.487789                      1.123325
# 12  2006-02-08            4.622024                      3.302075
# ...

# %%
# define your input variables and target variable
X = df[["temperature_mean_selection"]]
y = df["wind_eastward_mean_selection"]

# %%
# split your data into training and testing sets
train_size = int(0.8 * len(df))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# create a linear regression model
model = LinearRegression()

# train the model on the training data
model.fit(X_train, y_train)

# make predictions on the testing data
y_pred = model.predict(X_test)

# evaluate the performance of the model using the mean squared error
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

print("Mean squared error:", mse)

print('R2 value' , r2)
# use the model to make predictions on new data
X_new = pd.DataFrame({"temperature_mean_selection": [200, 200, 250]})
y_new = model.predict(X_new)

print("Predictions:", y_new)
# Out:
# Mean squared error: 33.523294613704614
# R2 value -10.28076118909461
# Predictions: [-1.89110239 -1.89110239 27.16806622]

# %%
x = df["temperature_mean_selection"].values.reshape(-1, 1)
y = df["wind_eastward_mean_selection"].values

# Create a linear regression model object
model = LinearRegression()

# Fit the model to the data
model.fit(x, y)

# Print the coefficient and intercept values
print('Coefficient:', model.coef_)
print('Intercept:', model.intercept_)
# Out:
# Coefficient: [0.69156131]
# Intercept: -143.6967576078839

# %%
r_squared = model.score(x, y)
print('R-squared:', r_squared)

# Compute the correlation coefficient
corr_coef = np.corrcoef(x.reshape(-1), y)[0, 1]
print('Correlation coefficient:', corr_coef)
# Out:
# R-squared: 0.5577538154336849
# Correlation coefficient: 0.7468291741982807
