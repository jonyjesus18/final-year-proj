# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# Load the data
data_path = 'processed_airs_sftp/40_km_grid/30km/mfx/2002-08-31_mfx.npz'
lat_file = '/Users/joaojesus/Desktop/final_year_proj/coordinates_40km_grid/Airs_nh_lat_40_grid.csv'
lon_file = '/Users/joaojesus/Desktop/final_year_proj/coordinates_40km_grid/Airs_nh_lon_40_grid.csv'

# Load the data into variables
data = np.load(data_path)['arr_0']
lat = np.genfromtxt(lat_file, delimiter=',')
lon = np.genfromtxt(lon_file, delimiter=',')

# %%
# Load the data into variables
data = np.load(data_path)['arr_0']


lat = pd.read_csv(lat_file, header=None).values.reshape(501, 501)
lon = pd.read_csv(lon_file, header=None).values.reshape(501, 501)

# Aggregate values based on longitude
aggregated_data = data.mean(axis=0)

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the aggregated data
ax.plot(lon[0], aggregated_data)

# Set the axis labels
ax.set_xlabel('Longitude')
ax.set_ylabel('Aggregated Data')

# Set the title
ax.set_title('Line Plot of Aggregated Data on 2002-08-31 at 30km Altitude')

# Show the plot
plt.show()
